# %% [markdown]
# # Notebook de nettoyage des données
#
# ## 1. Filtrage des features et produits

# %% [markdown]
# ### 1.1 Importation des données

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data = pd.read_csv('/home/fayz/Documents/OpenClassrooms/Projet2/food.csv', sep = "\t", low_memory = False)

# %%
data.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320772 entries, 0 to 320771
# Data columns (total 162 columns):
#  #    Column                                      Dtype
# ---   ------                                      -----
#  0    code                                        object
#  1    url                                         object
#  2    creator                                     object
#  3    created_t                                   object
#  4    created_datetime                            object
#  5    last_modified_t                             object
#  6    last_modified_datetime                      object
#  7    product_name                                object
#  8    generic_name                                object
#  9    quantity                                    object
#  10   packaging                                   object
#  11   packaging_tags                              object
#  12   brands                                      object
#  13   brands_tags                                 object
#  14   categories                                  object
#  15   categories_tags                             object
#  16   categories_fr                               object
#  17   origins                                     object
#  18   origins_tags                                object
#  19   manufacturing_places                        object
#  20   manufacturing_places_tags                   object
#  21   labels                                      object
#  22   labels_tags                                 object
#  23   labels_fr                                   object
#  24   emb_codes                                   object
#  25   emb_codes_tags                              object
#  26   first_packaging_code_geo                    object
#  27   cities                                      object
#  28   cities_tags                                 object
#  29   purchase_places                             object
#  30   stores                                      object
#  31   countries                                   object
#  32   countries_tags                              object
#  33   countries_fr                                object
#  34   ingredients_text                            object
#  35   allergens                                   object
#  36   allergens_fr                                object
#  37   traces                                      object
#  38   traces_tags                                 object
#  39   traces_fr                                   object
#  40   serving_size                                object
#  41   no_nutriments                               float64
#  42   additives_n                                 float64
#  43   additives                                   object
#  44   additives_tags                              object
#  45   additives_fr                                object
#  46   ingredients_from_palm_oil_n                 float64
#  47   ingredients_from_palm_oil                   float64
#  48   ingredients_from_palm_oil_tags              object
#  49   ingredients_that_may_be_from_palm_oil_n     float64
#  50   ingredients_that_may_be_from_palm_oil       float64
#  51   ingredients_that_may_be_from_palm_oil_tags  object
#  52   nutrition_grade_uk                          float64
#  53   nutrition_grade_fr                          object
#  54   pnns_groups_1                               object
#  55   pnns_groups_2                               object
#  56   states                                      object
#  57   states_tags                                 object
#  58   states_fr                                   object
#  59   main_category                               object
#  60   main_category_fr                            object
#  61   image_url                                   object
#  62   image_small_url                             object
#  63   energy_100g                                 float64
#  64   energy-from-fat_100g                        float64
#  65   fat_100g                                    float64
#  66   saturated-fat_100g                          float64
#  67   butyric-acid_100g                           float64
#  68   caproic-acid_100g                           float64
#  69   caprylic-acid_100g                          float64
#  70   capric-acid_100g                            float64
#  71   lauric-acid_100g                            float64
#  72   myristic-acid_100g                          float64
#  73   palmitic-acid_100g                          float64
#  74   stearic-acid_100g                           float64
#  75   arachidic-acid_100g                         float64
#  76   behenic-acid_100g                           float64
#  77   lignoceric-acid_100g                        float64
#  78   cerotic-acid_100g                           float64
#  79   montanic-acid_100g                          float64
#  80   melissic-acid_100g                          float64
#  81   monounsaturated-fat_100g                    float64
#  82   polyunsaturated-fat_100g                    float64
#  83   omega-3-fat_100g                            float64
#  84   alpha-linolenic-acid_100g                   float64
#  85   eicosapentaenoic-acid_100g                  float64
#  86   docosahexaenoic-acid_100g                   float64
#  87   omega-6-fat_100g                            float64
#  88   linoleic-acid_100g                          float64
#  89   arachidonic-acid_100g                       float64
#  90   gamma-linolenic-acid_100g                   float64
#  91   dihomo-gamma-linolenic-acid_100g            float64
#  92   omega-9-fat_100g                            float64
#  93   oleic-acid_100g                             float64
#  94   elaidic-acid_100g                           float64
#  95   gondoic-acid_100g                           float64
#  96   mead-acid_100g                              float64
#  97   erucic-acid_100g                            float64
#  98   nervonic-acid_100g                          float64
#  99   trans-fat_100g                              float64
#  100  cholesterol_100g                            float64
#  101  carbohydrates_100g                          float64
#  102  sugars_100g                                 float64
#  103  sucrose_100g                                float64
#  104  glucose_100g                                float64
#  105  fructose_100g                               float64
#  106  lactose_100g                                float64
#  107  maltose_100g                                float64
#  108  maltodextrins_100g                          float64
#  109  starch_100g                                 float64
#  110  polyols_100g                                float64
#  111  fiber_100g                                  float64
#  112  proteins_100g                               float64
#  113  casein_100g                                 float64
#  114  serum-proteins_100g                         float64
#  115  nucleotides_100g                            float64
#  116  salt_100g                                   float64
#  117  sodium_100g                                 float64
#  118  alcohol_100g                                float64
#  119  vitamin-a_100g                              float64
#  120  beta-carotene_100g                          float64
#  121  vitamin-d_100g                              float64
#  122  vitamin-e_100g                              float64
#  123  vitamin-k_100g                              float64
#  124  vitamin-c_100g                              float64
#  125  vitamin-b1_100g                             float64
#  126  vitamin-b2_100g                             float64
#  127  vitamin-pp_100g                             float64
#  128  vitamin-b6_100g                             float64
#  129  vitamin-b9_100g                             float64
#  130  folates_100g                                float64
#  131  vitamin-b12_100g                            float64
#  132  biotin_100g                                 float64
#  133  pantothenic-acid_100g                       float64
#  134  silica_100g                                 float64
#  135  bicarbonate_100g                            float64
#  136  potassium_100g                              float64
#  137  chloride_100g                               float64
#  138  calcium_100g                                float64
#  139  phosphorus_100g                             float64
#  140  iron_100g                                   float64
#  141  magnesium_100g                              float64
#  142  zinc_100g                                   float64
#  143  copper_100g                                 float64
#  144  manganese_100g                              float64
#  145  fluoride_100g                               float64
#  146  selenium_100g                               float64
#  147  chromium_100g                               float64
#  148  molybdenum_100g                             float64
#  149  iodine_100g                                 float64
#  150  caffeine_100g                               float64
#  151  taurine_100g                                float64
#  152  ph_100g                                     float64
#  153  fruits-vegetables-nuts_100g                 float64
#  154  collagen-meat-protein-ratio_100g            float64
#  155  cocoa_100g                                  float64
#  156  chlorophyl_100g                             float64
#  157  carbon-footprint_100g                       float64
#  158  nutrition-score-fr_100g                     float64
#  159  nutrition-score-uk_100g                     float64
#  160  glycemic-index_100g                         float64
#  161  water-hardness_100g                         float64
# dtypes: float64(106), object(56)
# memory usage: 396.5+ MB

# %% [markdown]
# ### 1.2 Prise de contact avec les features

# %%
col = data.columns
col_nombre = round(data.count()/max(data.count())*100,2)
print(col_nombre)
# Out:
# code                        99.99
# url                         99.99
# creator                    100.00
# created_t                  100.00
# created_datetime           100.00
#                             ...
# carbon-footprint_100g        0.08
# nutrition-score-fr_100g     68.96
# nutrition-score-uk_100g     68.96
# glycemic-index_100g          0.00
# water-hardness_100g          0.00
# Length: 162, dtype: float64

# %% [markdown]
# ### 1.3 Affichage du taux de remplissage des colonnes

# %%
col = data.columns
col_nombre = data.count()
plt.title('Taux de remplissage des colonnes')
plt.xlabel('Numéro de colonne')
plt.ylabel('Taux de non vide en %')
plt.bar(range(len(col)),col_nombre/col_nombre[0]*100)
plt.axhline(y=50,xmin = 0, xmax = len(col))
plt.show()

# %% [markdown]
# ### 1.4 Traitement des colonnes vides

# %%
print("Nom des colonnes vides")
print(col[col_nombre == 0])
# Out:
# Nom des colonnes vides
# Index(['no_nutriments', 'ingredients_from_palm_oil',
#        'ingredients_that_may_be_from_palm_oil', 'nutrition_grade_uk',
#        'butyric-acid_100g', 'caproic-acid_100g', 'lignoceric-acid_100g',
#        'cerotic-acid_100g', 'melissic-acid_100g', 'elaidic-acid_100g',
#        'mead-acid_100g', 'erucic-acid_100g', 'nervonic-acid_100g',
#        'chlorophyl_100g', 'glycemic-index_100g', 'water-hardness_100g'],
#       dtype='object')

# %%
data.drop(data[col[col_nombre==0]], axis = 1, inplace = True)

# %% [markdown]
# **En retirant toutes les colonnes vides, on passe de 162 à 146 colonnes**

# %%
col = data.columns
col_nombre = data.count()
plt.title('Taux de remplissage des colonnes')
plt.xlabel("Numéro de colonne")
plt.ylabel("Taux de non vide en %")
plt.bar(range(len(col)),col_nombre/col_nombre[0]*100)
plt.axhline(y=50,xmin = 0, xmax = len(col))
plt.show()

# %%
data = data.reset_index()

# %% [markdown]
# ### 1.5 Filtre sur les données françaises

# %% [markdown]
# **On ne s'intérresse qu'aux produits français et on veut proposer un produit avec un meilleur nutriscore de la même catégorie, on peut supprimer les produits d'autres pays**

# %%
print('Les 11 premiers pays représentent', round(sum(data['countries_fr'].value_counts()[0:10])/max(data.count())*100,2),'% du total')
data['countries_fr'].value_counts()[0:10].plot.pie()
plt.ylabel("Proportion par pays")
plt.show()
# Out:
# Les 11 premiers pays représentent 95.78 % du total

# %%
data_fr = data[data.countries_fr == "France"]
data_fr = data_fr.reset_index()

# %%
print("Après filtre on a encore",round(data_fr.shape[0]/data.shape[0]*100,2),'% de données')
print("Notre nouveau jeu de données compte : ", data_fr.shape[0], "lignes et", data_fr.shape[1], "colonnes avant nettoyage.")
# Out:
# Après filtre on a encore 29.43 % de données
# Notre nouveau jeu de données compte :  94392 lignes et 148 colonnes avant nettoyage.

# %%
col = data_fr.columns
col_nombre = data_fr.count()
data_fr.drop(data_fr[col[col_nombre==0]], axis = 1, inplace = True)

# %% [markdown]
# ### 1.6 Suppression des colonnes inutiles

# %%
round(data_fr.count()/max(data_fr.count())*100,2)
# Out:
# level_0                             100.00
# index                               100.00
# code                                100.00
# url                                 100.00
# creator                             100.00
#                                      ...
# collagen-meat-protein-ratio_100g      0.17
# cocoa_100g                            0.62
# carbon-footprint_100g                 0.18
# nutrition-score-fr_100g              61.98
# nutrition-score-uk_100g              61.98
# Length: 138, dtype: float64

# %%
tup = []
a = data_fr.count()<max(data_fr.count())*0.4
for i in range(len(a)):
    if (a[i] == True):
        tup.append(a.index[i])

# %%
data_fr.drop(tup, axis = 1, inplace = True)

# %%
col = data_fr.columns
col_nombre = data_fr.count()
plt.title('Taux de remplissage des colonnes')
plt.xlabel("Numéro de colonne")
plt.ylabel("Taux de non vide en %")
plt.bar(range(len(col)),col_nombre/col_nombre[0]*100)
plt.axhline(y=50,xmin = 0, xmax = len(col))
plt.show()

# %% [markdown]
# **On garde les features qui nous intéresse parmi les premières triée**

# %%
keep = ['product_name',\
        'brands',\
        'additives_n',\
        'packaging',\
        'nutrition_grade_fr',\
        'pnns_groups_1',\
        'pnns_groups_2',\
        'energy_100g',\
        'fat_100g',\
        'saturated-fat_100g',\
        'carbohydrates_100g',\
        'sugars_100g',\
        'fiber_100g',\
        'proteins_100g',\
        'salt_100g']
data_fr = data_fr.iloc[:,data_fr.columns.isin(keep)]

# %%
col = data_fr.columns
col_nombre = data_fr.count()
plt.title('Taux de remplissage des colonnes')
plt.ylabel("Nom de colonne")
plt.xlabel("Taux de non vide en %")
plt.xticks(rotation = 90)
plt.barh(col,col_nombre/col_nombre[0]*100)
plt.axvline(x=50)
plt.show()

# %% [markdown]
# ### 1.7 Filtre sur les produits sans nom et suppressions des doublons

# %%
data_fr.product_name.isna().value_counts()
# Out:
# False    87398
# True      6994
# Name: product_name, dtype: int64

# %%
data_fr = data_fr[data_fr.product_name.isna()==False]

# %%
data_fr = data_fr.reset_index()
data_fr.drop('index',axis = 1,inplace = True)

# %%
data_fr.head()
# Out:
#                         product_name         packaging            brands  \
# 0                 Farine de blé noir               NaN   Ferme t'y R'nao
# 1                      Filet de bœuf         plastique               NaN
# 2                            Twix x2               NaN               NaN
# 3                  lentilles vertes   Sachet plastique  Bertrand Lejeune
# 4  Biscuits sablés fourrage au cacao      Carton,boîte         St Michel
#
#    additives_n nutrition_grade_fr         pnns_groups_1       pnns_groups_2  \
# 0          NaN                NaN                   NaN                 NaN
# 1          NaN                NaN               unknown             unknown
# 2          NaN                NaN               unknown             unknown
# 3          0.0                NaN  Cereals and potatoes             Legumes
# 4          3.0                NaN         Sugary snacks  Biscuits and cakes
#
#    energy_100g  fat_100g  saturated-fat_100g  carbohydrates_100g  sugars_100g  \
# 0          NaN       NaN                 NaN                 NaN          NaN
# 1          NaN       NaN                 NaN                 NaN          NaN
# 2          NaN       NaN                 NaN                 NaN          NaN
# 3          NaN       NaN                 NaN                 NaN          NaN
# 4          NaN       NaN                 NaN                 NaN          NaN
#
#    fiber_100g  proteins_100g  salt_100g
# 0         NaN            NaN        NaN
# 1         NaN            NaN        NaN
# 2         NaN            NaN        NaN
# 3         NaN            NaN        NaN
# 4         NaN            NaN        NaN

# %%
print(data_fr.duplicated().value_counts())
# Out:
# False    86881
# True       517
# dtype: int64

# %%
df = data_fr.drop_duplicates()
df = df.reset_index()
df.drop('index',axis = 1,inplace = True)
print(df.duplicated().value_counts())
# Out:
# False    86881
# dtype: int64

# %%
round(df.count()/max(df.count())*100,2)
# Out:
# product_name          100.00
# packaging              63.85
# brands                 93.72
# additives_n            57.87
# nutrition_grade_fr     66.84
# pnns_groups_1          69.27
# pnns_groups_2          71.48
# energy_100g            70.19
# fat_100g               50.85
# saturated-fat_100g     67.86
# carbohydrates_100g     50.38
# sugars_100g            67.96
# fiber_100g             49.93
# proteins_100g          69.90
# salt_100g              68.03
# dtype: float64

# %%
col = data_fr.columns
col_nombre = data_fr.count()
plt.title('Taux de remplissage des colonnes')
plt.ylabel("Nom de colonne")
plt.xlabel("Taux de non vide en %")
plt.xticks(rotation = 90)
plt.barh(col,col_nombre/col_nombre[0]*100)
plt.axvline(x=50)
plt.show()

# %% [markdown]
# ## 2. Traitement des valeurs aberrantes

# %% [markdown]
# ### 2.1 Apercu général

# %%
df.describe()
# Out:
#         additives_n   energy_100g      fat_100g  saturated-fat_100g  \
# count  50282.000000  6.098000e+04  44179.000000        58954.000000
# mean       1.858777  1.167765e+03     13.276896            5.387137
# std        2.567380  1.320636e+04     16.981752            8.540098
# min        0.000000  0.000000e+00      0.000000            0.000000
# 25%        0.000000  4.270000e+02      1.300000            0.300000
# 50%        1.000000  1.029000e+03      6.800000            1.900000
# 75%        3.000000  1.639000e+03     21.000000            7.300000
# max       31.000000  3.251373e+06    380.000000          210.000000
#
#        carbohydrates_100g   sugars_100g    fiber_100g  proteins_100g  \
# count         43767.00000  59044.000000  43378.000000   60731.000000
# mean             27.32515     13.236850      2.525191       7.799500
# std              27.31311     19.024517      4.643673       7.933839
# min               0.00000     -0.100000      0.000000       0.000000
# 25%               4.00000      1.000000      0.000000       1.800000
# 50%              14.00000      4.000000      1.300000       6.000000
# 75%              52.70000     17.000000      3.200000      11.000000
# max             190.00000    105.000000    178.000000     100.000000
#
#           salt_100g
# count  59102.000000
# mean       1.162860
# std        4.303963
# min        0.000000
# 25%        0.080000
# 50%        0.570000
# 75%        1.250000
# max      211.000000

# %%
plt.subplots(figsize = (10,10))
df.boxplot()
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### 2.2 Traitement de chaque colonne

# %% [markdown]
# #### Energy_100g

# %%
plt.plot(df.energy_100g)

# %%
print('Pourcentage de valeur à neutraliser : ',round(df.loc[df.energy_100g>4000,'energy_100g'].count()/df.energy_100g.count()*100,2),'%')
# Out:
# Pourcentage de valeur à neutraliser :  0.13 %

# %%
df.loc[df.energy_100g>4000,'energy_100g'] = np.nan

# %%
plt.title("Quantité d'énergie par produit")
plt.ylabel('Energie')
plt.xlabel('Numéro de produit')
plt.plot(df.energy_100g)
plt.show()

# %% [markdown]
# #### Fat_100g

# %%
print('Pourcentage de valeur à neutraliser : ',round(df.loc[df.fat_100g>100,'fat_100g'].count()/df.fat_100g.count()*100,2),'%')
# Out:
# Pourcentage de valeur à neutraliser :  0.0 %

# %%
df[df['fat_100g']>100]
# Out:
#                                      product_name                   packaging  \
# 59813  mini choux goût fromage de chèvre - poivre  étui carton,film plastique
# 82196                    Graine de couscous moyen                Boîte carton
#
#                 brands  additives_n nutrition_grade_fr         pnns_groups_1  \
# 59813           Auchan          7.0                  e          Salty snacks
# 82196  La méditerranéa          NaN                  a  Cereals and potatoes
#
#       pnns_groups_2  energy_100g  fat_100g  saturated-fat_100g  \
# 59813    Appetizers          NaN     380.0               210.0
# 82196       Cereals       1482.0     105.0                 0.3
#
#        carbohydrates_100g  sugars_100g  fiber_100g  proteins_100g  salt_100g
# 59813               190.0         22.7         0.0            0.0       9.33
# 82196                70.0          2.5         NaN           12.0       0.01

# %% [markdown]
# Il s'agit très clairement d'erreurs

# %%
plt.title("Quantité de lipides par produit")
plt.ylabel('Lipides')
plt.xlabel('Numéro de produit')
df.loc[df.fat_100g>100,'fat_100g'] = np.nan
plt.plot(df.fat_100g)
plt.axhline(y=82)
plt.show()

# %%
df[df['fat_100g']==100]['pnns_groups_2'].value_counts()
# Out:
# Fats                    252
# unknown                   6
# Dressings and sauces      2
# Name: pnns_groups_2, dtype: int64

# %% [markdown]
# Quelques erreurs dans le dataset, aucun snack n'est fait à 100% de graisses

# %% [markdown]
# #### Satured-fat_100g

# %%
print('Pourcentage de valeur à neutraliser : ',round(df.loc[df['saturated-fat_100g']>100,'saturated-fat_100g'].count()/df['saturated-fat_100g'].count()*100,2),'%')
# Out:
# Pourcentage de valeur à neutraliser :  0.0 %

# %%
plt.title("Quantité d'acides gras saturé par produit")
plt.ylabel('acides gras saturé')
plt.xlabel('Numéro de produit')
df.loc[df['saturated-fat_100g']>100,'saturated-fat_100g'] = np.nan
plt.plot(df['saturated-fat_100g'])
plt.show()

# %%
df[df['saturated-fat_100g']==100]
# Out:
#                               product_name packaging      brands  additives_n  \
# 3196                     Frites & Fritures    carton   Vita d'Or          0.0
# 6603                              Jog'Frit    Carton    Jog'Frit          0.0
# 37418  Huile De Tournesol Végétale 2 Litre       NaN   Carrefour          NaN
# 73922         Végétaline (offre familiale)    Carton  Végétaline          NaN
# 77409                                  Eau       NaN       Vital          NaN
#
#       nutrition_grade_fr   pnns_groups_1 pnns_groups_2  energy_100g  fat_100g  \
# 3196                   e  Fat and sauces          Fats       3700.0     100.0
# 6603                   e  Fat and sauces          Fats       3700.0     100.0
# 37418                  e             NaN           NaN       3766.0       NaN
# 73922                  d  Fat and sauces          Fats       3700.0     100.0
# 77409                  e             NaN           NaN        418.0       NaN
#
#        saturated-fat_100g  carbohydrates_100g  sugars_100g  fiber_100g  \
# 3196                100.0                 0.0          0.0         NaN
# 6603                100.0                 0.0          0.0         NaN
# 37418               100.0                 NaN          0.0         0.0
# 73922               100.0                 0.0          0.0         NaN
# 77409               100.0                 NaN        100.0       100.0
#
#        proteins_100g  salt_100g
# 3196             0.0        0.0
# 6603             0.0        0.0
# 37418            0.0        0.0
# 73922            0.0        0.0
# 77409          100.0        2.0

# %% [markdown]
# Informations cohérentes avec la source :
# https://fr.openfoodfacts.org/produit/20022082/frites-fritures-vita-d-or
#
# Erreur tout de même sur l'eau

# %% [markdown]
# #### Carbohydrates_100g

# %%
print('Pourcentage de valeur à neutraliser : ',round(df.loc[df['carbohydrates_100g']>100,'carbohydrates_100g'].count()/df['carbohydrates_100g'].count()*100,2),'%')
# Out:
# Pourcentage de valeur à neutraliser :  0.02 %

# %%
plt.title("Quantité de glucides par produit")
plt.ylabel('Glucides')
plt.xlabel('Numéro de produit')
df.loc[df['carbohydrates_100g']>100,'carbohydrates_100g'] = np.nan
plt.plot(df['carbohydrates_100g'])
plt.show()

# %%
df[df['carbohydrates_100g']==100]
# Out:
#                                           product_name  \
# 1744                                         cassonade
# 4183                                Sucres en morceaux
# 6574                    Cassonade Sucre roux en poudre
# 12276                               Sucre semoule fine
# 15544                                Sucre Glace Daddy
# 15547                      Petits cubes pure canne bio
# 15548                                  Sucre en poudre
# 15549                             Cassonade Pure Canne
# 15550                       Sucre extra fin à patisser
# 15553                             Sucre pure canne bio
# 16434                                    Sucre cristal
# 16435                          Sucre poudre Béghin Say
# 16436                                     Sucre Poudre
# 16444                    Sucre roux de canne en poudre
# 16446                           La Perruche Pure Canne
# 16452                           La Perruche pure canne
# 16456                                   Blond de Canne
# 16458                                     Sucre poudre
# 17119                             Fructose Cristallisé
# 19515                                    Sucre vanillé
# 21233  Poudre cristallisée à base de bouleau - Xylitol
# 24598                            Sucre en Morceaux n°4
# 24599                                  Sucre en poudre
# 24688                                Sucre à confiture
# 33743                                  Sucre en poudre
# 37575                    Sucre Blond de canne Morceaux
# 43947                Fructose pur cristallisé Monoprix
# 44351                                  Sucre en poudre
# 46282        Veritable bonbon au coquelicot de nemours
# 47186                                  Sucre en poudre
# 47284                                Sucre en morceaux
# 48864                                            Sucre
# 49480                         Sucre en morceaux, blanc
# 49481                            Sucre en poudre blanc
# 49528                                  Sucre en poudre
# 50840                              Miel de châtaignier
# 56750                      Dosettes de sucre en poudre
# 57364                            Sucre petits morceaux
# 60165                                Sucre en morceaux
# 60166                                  Sucre en poudre
# 61189                                  Sucre en poudre
# 61311                                      Sucre Glace
# 61676                                Sucre en morceaux
# 62927                            Sucre blanc en poudre
# 64370                            Sucre en morceaux n°4
# 64371                                  Sucre en poudre
# 64917                         SUCRE CANNE ROUX MORCEAU
# 69319                                  Sucre en poudre
# 73830                           Super Puff Candy Floss
# 74873                                Sucre en morceaux
# 77294                                      Candy Floss
# 82950                                   Sucre de canne
# 82951                                  Sucre en poudre
# 84133                                      Sucre blanc
# 85470                            Morceaux de sucre N°4
# 85856                                  Sucre Vanilliné
#
#                                                packaging  \
# 1744                                              carton
# 4183                                 boite,carton,paquet
# 6574                                              carton
# 12276                                      Paquet,paquet
# 15544             Plastique,pot,boîte verseuse,plastique
# 15547                                             carton
# 15548                        plastique,doypack,Plastique
# 15549                        plastique,Doypack,Plastique
# 15550  Pochette & embout refermable plastique,pochett...
# 15553                                   Sachet,Plastique
# 16434  Sachet papier,Point vert,Sachet papier à recyc...
# 16435                        boite,carton,boîte verseuse
# 16436                                       Boite,Carton
# 16444                                      Carton,carton
# 16446                                             Carton
# 16452                                             Carton
# 16456                                   Sachet,Plastique
# 16458                           doypack,sachet,plastique
# 17119                       Boîte,Carton,Métal,Plastique
# 19515                        Film,Plastique,Sachet,Métal
# 21233                                   Sachet,Plastique
# 24598                                             Carton
# 24599                                                NaN
# 24688                                      papier,sachet
# 33743                                             carton
# 37575                                             Carton
# 43947                                             carton
# 44351                                      Sachet,Papier
# 46282                                                NaN
# 47186                                      sachet,papier
# 47284                                      carton,paquet
# 48864                                   Sachet,Plastique
# 49480                                       Carton,boîte
# 49481                                      Paquet,paquet
# 49528                                       Boîte,Carton
# 50840                                                NaN
# 56750                          Sachet,Papier,Etui,Carton
# 57364                                             Carton
# 60165                                 Boîte,Carton,boîte
# 60166                                      Sachet,Papier
# 61189                                      Sachet,Papier
# 61311                                  Pot,Plastique,pot
# 61676                                       boîte,carton
# 62927                                      Sachet,Papier
# 64370                                             Carton
# 64371                                      Papier,papier
# 64917                                                NaN
# 69319                               Sachet,Papier,sachet
# 73830                                     seau,plastique
# 74873                                             Carton
# 77294                                     seau,plastique
# 82950                                             Carton
# 82951                                      Sachet,Papier
# 84133  Sachet papier,es:Cartón,pt:Cartão,Point vert,s...
# 85470                                             Carton
# 85856                                   Sachet,plastique
#
#                              brands  additives_n nutrition_grade_fr  \
# 1744                        Erstein          0.0                NaN
# 4183                        Navarre          0.0                  d
# 6574                      Sucandise          NaN                  d
# 12276                       Erstein          0.0                NaN
# 15544               Daddy,CristalCo          0.0                  d
# 15547                         Daddy          0.0                  d
# 15548                         Daddy          0.0                  d
# 15549                         Daddy          0.0                  d
# 15550                Daddy,CritalCo          1.0                  d
# 15553                         Daddy          0.0                  d
# 16434             Béghin Say,Tereos          0.0                  d
# 16435                    Béghin Say          0.0                  d
# 16436                    Béghin Say          0.0                  d
# 16444                    Béghin Say          0.0                  d
# 16446                    Béghin Say          0.0                  d
# 16452                    Beghin say          0.0                  d
# 16456       Blonvilliers,Béghin Say          0.0                  d
# 16458                    Beghin say          0.0                  d
# 17119                         Vivis          0.0                NaN
# 19515                        Casino          0.0                  d
# 21233                         Vivis          1.0                  b
# 24598                         Netto          0.0                  d
# 24599                         Netto          NaN                  d
# 24688                         Netto          2.0                  d
# 33743                  Leader Price          0.0                  d
# 37575                 Carrefour Bio          0.0                  d
# 43947                      Monoprix          0.0                  d
# 44351  Monoprix P'tit Prix,Monoprix          0.0                  d
# 46282              Des Lis Chocolat          1.0                  c
# 47186        Top Budget,Intermarché          0.0                  d
# 47284                    Top budget          0.0                  d
# 48864                    Rochambeau          0.0                NaN
# 49480                  Eco+,Scamark          0.0                  d
# 49481                         Eco +          0.0                  d
# 49528                          Eco+          0.0                  d
# 50840             Provenance Nature          0.0                  e
# 56750            Téva,Marque Repère          NaN                  d
# 57364            Téva,Marque repère          NaN                  d
# 60165                         Pouce          0.0                  d
# 60166            Pouce,Auchan Pouce          0.0                  d
# 61189                        Auchan          0.0                  d
# 61311                        Auchan          0.0                  d
# 61676                        Auchan          0.0                  d
# 62927                     Bien Vu !          0.0                NaN
# 64370                Tous les jours          0.0                  d
# 64371                        Casino          0.0                  d
# 64917                           L&H          0.0                  d
# 69319                       DIAMANT          0.0                  d
# 73830                       Pimlico          3.0                  d
# 74873                         Winny          0.0                  d
# 77294                         AdMaR          4.0                  d
# 82950                        Sucran          0.0                NaN
# 82951                        Sucran          0.0                  d
# 84133                           Dia          0.0                  d
# 85470                   Sans marque          0.0                  d
# 85856                 Alsa,Unilever          0.0                  d
#
#        pnns_groups_1 pnns_groups_2  energy_100g  fat_100g  saturated-fat_100g  \
# 1744   Sugary snacks        Sweets       1674.0       0.0                 NaN
# 4183   Sugary snacks        Sweets       1699.0       0.0                 0.0
# 6574   Sugary snacks        Sweets       1700.0       0.0                 0.0
# 12276  Sugary snacks        Sweets       1674.0       NaN                 NaN
# 15544  Sugary snacks        Sweets       1700.0       0.0                 0.0
# 15547  Sugary snacks        Sweets       1700.0       0.0                 0.0
# 15548  Sugary snacks        Sweets       1700.0       0.0                 0.0
# 15549  Sugary snacks        Sweets       1674.0       0.0                 0.0
# 15550  Sugary snacks        Sweets       1674.0       0.0                 0.0
# 15553  Sugary snacks        Sweets       1700.0       0.0                 0.0
# 16434  Sugary snacks        Sweets       1700.0       0.0                 0.0
# 16435  Sugary snacks        Sweets       1700.0       0.0                 0.0
# 16436  Sugary snacks        Sweets       1700.0       0.0                 0.0
# 16444  Sugary snacks        Sweets       1700.0       0.0                 0.0
# 16446  Sugary snacks        Sweets       1700.0       0.0                 0.0
# 16452        unknown       unknown       1674.0       0.0                 0.0
# 16456  Sugary snacks        Sweets       1700.0       0.0                 0.0
# 16458  Sugary snacks        Sweets       1674.0       0.0                 0.0
# 17119  Sugary snacks        Sweets       1700.0       NaN                 NaN
# 19515  Sugary snacks        Sweets       1700.0       0.0                 0.0
# 21233        unknown       unknown       1000.0       0.5                 0.1
# 24598  Sugary snacks        Sweets       1700.0       0.5                 0.1
# 24599  Sugary snacks        Sweets       1700.0       0.5                 0.1
# 24688  Sugary snacks        Sweets       1700.0       0.5                 0.1
# 33743  Sugary snacks        Sweets       1700.0       0.0                 0.0
# 37575  Sugary snacks        Sweets       1692.0       0.0                 0.0
# 43947  Sugary snacks        Sweets       1700.0       0.0                 0.0
# 44351  Sugary snacks        Sweets       1700.0       0.0                 0.0
# 46282        unknown       unknown       1674.0       0.0                 0.0
# 47186  Sugary snacks        Sweets       1700.0       0.5                 0.1
# 47284  Sugary snacks        Sweets       1700.0       0.5                 0.1
# 48864  Sugary snacks        Sweets       1674.0       0.0                 NaN
# 49480  Sugary snacks        Sweets       1700.0       0.0                 0.0
# 49481  Sugary snacks        Sweets       1700.0       0.0                 0.0
# 49528  Sugary snacks        Sweets       1700.0       0.0                 0.0
# 50840        unknown       unknown       3347.0       0.0                 0.0
# 56750  Sugary snacks        Sweets       1700.0       0.0                 0.0
# 57364  Sugary snacks        Sweets       1700.0       0.0                 0.0
# 60165  Sugary snacks        Sweets       1699.0       0.0                 0.0
# 60166  Sugary snacks        Sweets       1700.0       0.0                 0.0
# 61189  Sugary snacks        Sweets       1700.0       0.0                 0.0
# 61311  Sugary snacks        Sweets       1700.0       0.0                 0.0
# 61676  Sugary snacks        Sweets       1698.0       0.0                 0.0
# 62927  Sugary snacks        Sweets          NaN       NaN                 NaN
# 64370  Sugary snacks        Sweets       1700.0       0.0                 0.0
# 64371  Sugary snacks        Sweets       1700.0       0.0                 0.0
# 64917        unknown       unknown       1674.0       0.0                 0.0
# 69319  Sugary snacks        Sweets       1674.0       0.0                 0.0
# 73830  Sugary snacks        Sweets       1694.0       0.0                 0.0
# 74873  Sugary snacks        Sweets       1700.0       0.0                 0.0
# 77294  Sugary snacks        Sweets       1694.0       0.0                 0.0
# 82950  Sugary snacks        Sweets       1615.0       0.0                 NaN
# 82951  Sugary snacks        Sweets       1700.0       0.0                 0.0
# 84133  Sugary snacks        Sweets       1700.0       0.0                 0.0
# 85470  Sugary snacks        Sweets       1700.0       0.0                 0.0
# 85856  Sugary snacks        Sweets       1700.0       0.1                 0.1
#
#        carbohydrates_100g  sugars_100g  fiber_100g  proteins_100g  salt_100g
# 1744                100.0          NaN         NaN            0.0        NaN
# 4183                100.0        100.0         0.0            1.0   0.000000
# 6574                100.0        100.0         0.0            0.0   0.000000
# 12276               100.0        100.0         NaN            NaN        NaN
# 15544               100.0         98.0         NaN            2.0   0.000000
# 15547               100.0        100.0         NaN            0.0   0.000000
# 15548               100.0        100.0         NaN            0.0   0.000000
# 15549               100.0        100.0         0.0            0.0   0.000000
# 15550               100.0        100.0         NaN            0.0   0.000000
# 15553               100.0        100.0         NaN            0.0   0.000000
# 16434               100.0        100.0         NaN            0.0   0.000000
# 16435               100.0        100.0         NaN            0.0   0.000000
# 16436               100.0        100.0         0.0            0.0   0.000000
# 16444               100.0        100.0         NaN            0.0   0.000000
# 16446               100.0        100.0         NaN            0.0   0.000000
# 16452               100.0        100.0         0.0            0.0   0.000000
# 16456               100.0        100.0         NaN            0.0   0.000000
# 16458               100.0        100.0         0.0            0.0   0.000000
# 17119               100.0          NaN         NaN            NaN        NaN
# 19515               100.0         95.0         NaN            0.0   0.000000
# 21233               100.0          0.5         0.5            0.5   0.012700
# 24598               100.0        100.0         0.0            0.0   0.010008
# 24599               100.0        100.0         NaN            0.5   0.010000
# 24688               100.0         96.0         NaN            0.5   0.040000
# 33743               100.0        100.0         NaN            0.0   0.000000
# 37575               100.0        100.0         NaN            0.0   0.000000
# 43947               100.0        100.0         0.0            0.0   0.000000
# 44351               100.0        100.0         NaN            0.0   0.000000
# 46282               100.0          0.0         NaN            0.0   0.000000
# 47186               100.0        100.0         NaN            0.5   0.010000
# 47284               100.0        100.0         NaN            0.5   0.010000
# 48864               100.0          NaN         NaN            0.0        NaN
# 49480               100.0        100.0         0.0            0.0   0.000000
# 49481               100.0        100.0         0.0            0.0   0.000000
# 49528               100.0        100.0         0.0            0.0   0.000000
# 50840               100.0        100.0         0.0            0.0   0.000000
# 56750               100.0        100.0         0.0            0.0   0.000000
# 57364               100.0        100.0         0.0            0.0   0.000000
# 60165               100.0        100.0         0.0            0.0   0.000000
# 60166               100.0        100.0         0.0            0.0   0.000000
# 61189               100.0        100.0         NaN            0.0   0.000000
# 61311               100.0         97.0         0.0            0.0   0.000000
# 61676               100.0        100.0         NaN            0.0   0.000000
# 62927               100.0        100.0         NaN            NaN        NaN
# 64370               100.0        100.0         NaN            0.0   0.000000
# 64371               100.0        100.0         NaN            0.0   0.000000
# 64917               100.0        100.0         NaN            0.0   0.000000
# 69319               100.0        100.0         NaN            0.0   0.000000
# 73830               100.0        100.0         NaN            0.0   0.000000
# 74873               100.0        100.0         NaN            0.0   0.000000
# 77294               100.0        100.0         NaN            0.0   0.000000
# 82950               100.0          NaN         NaN            0.0        NaN
# 82951               100.0        100.0         0.0            0.0   0.000000
# 84133               100.0        100.0         0.0            0.0   0.000000
# 85470               100.0        100.0         0.0            0.0   0.000000
# 85856               100.0        100.0         NaN            0.1   0.013000

# %% [markdown]
# Données cohérentes

# %% [markdown]
# #### Sugars_100g

# %%
print('Pourcentage de valeur à neutraliser : ',round(df.loc[df['sugars_100g']>100,'sugars_100g'].count()/df['sugars_100g'].count()*100,2),'%')
# Out:
# Pourcentage de valeur à neutraliser :  0.01 %

# %%
print('Pourcentage de valeur à neutraliser : ',round(df.loc[df['sugars_100g']<0,'sugars_100g'].count()/df['sugars_100g'].count()*100,2),'%')
# Out:
# Pourcentage de valeur à neutraliser :  0.0 %

# %%
df.loc[df['sugars_100g']>100,'sugars_100g'] = np.nan
df.loc[df['sugars_100g']<0,'sugars_100g'] = np.nan
plt.title("Quantité de sucres par produit")
plt.ylabel('Sucre')
plt.xlabel('Numéro de produit')
plt.plot(df['sugars_100g'])
plt.show()

# %%
df[df['sugars_100g']==100]
# Out:
#                          product_name  \
# 4183               Sucres en morceaux
# 5403                        Cassonade
# 6574   Cassonade Sucre roux en poudre
# 12276              Sucre semoule fine
# 12279              Sucre semoule fine
# ...                               ...
# 82951                 Sucre en poudre
# 83630             Sucre roux de canne
# 84133                     Sucre blanc
# 85470           Morceaux de sucre N°4
# 85856                 Sucre Vanilliné
#
#                                                packaging         brands  \
# 4183                                 boite,carton,paquet        Navarre
# 5403                                             produit        Navarre
# 6574                                              carton      Sucandise
# 12276                                      Paquet,paquet        Erstein
# 12279                                          plastique        Erstein
# ...                                                  ...            ...
# 82951                                      Sachet,Papier         Sucran
# 83630                                       Boite,Carton            Dia
# 84133  Sachet papier,es:Cartón,pt:Cartão,Point vert,s...            Dia
# 85470                                             Carton    Sans marque
# 85856                                   Sachet,plastique  Alsa,Unilever
#
#        additives_n nutrition_grade_fr  pnns_groups_1 pnns_groups_2  \
# 4183           0.0                  d  Sugary snacks        Sweets
# 5403           NaN                  d            NaN           NaN
# 6574           NaN                  d  Sugary snacks        Sweets
# 12276          0.0                NaN  Sugary snacks        Sweets
# 12279          0.0                  d        unknown       unknown
# ...            ...                ...            ...           ...
# 82951          0.0                  d  Sugary snacks        Sweets
# 83630          0.0                  d  Sugary snacks        Sweets
# 84133          0.0                  d  Sugary snacks        Sweets
# 85470          0.0                  d  Sugary snacks        Sweets
# 85856          0.0                  d  Sugary snacks        Sweets
#
#        energy_100g  fat_100g  saturated-fat_100g  carbohydrates_100g  \
# 4183        1699.0       0.0                 0.0               100.0
# 5403        1674.0       NaN                 0.5                 NaN
# 6574        1700.0       0.0                 0.0               100.0
# 12276       1674.0       NaN                 NaN               100.0
# 12279       1674.0       NaN                 0.0                 NaN
# ...            ...       ...                 ...                 ...
# 82951       1700.0       0.0                 0.0               100.0
# 83630       1674.0       NaN                 0.0                 NaN
# 84133       1700.0       0.0                 0.0               100.0
# 85470       1700.0       0.0                 0.0               100.0
# 85856       1700.0       0.1                 0.1               100.0
#
#        sugars_100g  fiber_100g  proteins_100g  salt_100g
# 4183         100.0         0.0            1.0      0.000
# 5403         100.0         0.0            0.5      0.010
# 6574         100.0         0.0            0.0      0.000
# 12276        100.0         NaN            NaN        NaN
# 12279        100.0         0.0            0.0      0.000
# ...            ...         ...            ...        ...
# 82951        100.0         0.0            0.0      0.000
# 83630        100.0         0.0            0.0      0.000
# 84133        100.0         0.0            0.0      0.000
# 85470        100.0         0.0            0.0      0.000
# 85856        100.0         NaN            0.1      0.013
#
# [79 rows x 15 columns]

# %% [markdown]
# Données cohérentes

# %% [markdown]
# #### Fiber_100g

# %%
print('Pourcentage de valeur à neutraliser : ',round(df.loc[df['fiber_100g']>20,'fiber_100g'].count()/df['fiber_100g'].count()*100,2),'%')
# Out:
# Pourcentage de valeur à neutraliser :  0.87 %

# %%
df.loc[df['fiber_100g']>20,'fiber_100g'] = np.nan
plt.title("Quantité de fibres par produit")
plt.ylabel('fibres')
plt.xlabel('Numéro de produit')
plt.plot(df['fiber_100g'])
plt.show()

# %%
df[df['fiber_100g']==20]
# Out:
#                                         product_name  \
# 512                            Pain Seigle au Sésame
# 10896                        Mélange pour Minestrone
# 21133                                    Superlevure
# 35672                        Lentilles vertes du Puy
# 35783  Chocolat Noir 72% de Cacao Aux Fèves De Cacao
# 35787                     Chocolat Noir 72% de Cacao
# 39150                        Pommes golden delicious
# 40977                      Tripes Au Boeuf Et Jambon
# 60706                              Lentilles blondes
# 64677                                     Mix Salade
# 69736                       Flocons de levure maltée
# 74374                              Crispbread Sesame
# 76931           Eveil Du Bouddha Chanvre Sans Gluten
# 77031                            L' Éveil du Bouddha
# 77943                                       Volkoren
# 77946                   Wasa Knäckebrod Lichtgewicht
#
#                        packaging           brands  additives_n  \
# 512                          NaN           Ryvita          NaN
# 10896           Sachet,Plastique    Vivien Paille          0.0
# 21133               Flacon,Verre  Gayelord Hauser          0.0
# 35672                        NaN    La Vie Claire          NaN
# 35783                        NaN    La Vie Claire          NaN
# 35787  Tablette,Aluminium,papier    La Vie Claire          0.0
# 39150                        NaN          Cardeli          NaN
# 40977                        NaN      Le Revelois          NaN
# 60706                        NaN           Auchan          NaN
# 64677                  plastique  Moulin d'Amhara          0.0
# 69736                     Carton         Rapunzel          0.0
# 74374                        NaN         Delhaize          NaN
# 76931                        NaN           Iswari          NaN
# 77031                        NaN           Iswari          NaN
# 77943                        NaN       Gwada kola          NaN
# 77946                        NaN             Wasa          NaN
#
#       nutrition_grade_fr         pnns_groups_1       pnns_groups_2  \
# 512                    a  Cereals and potatoes             Cereals
# 10896                  a  Cereals and potatoes             Legumes
# 21133                  a               unknown             unknown
# 35672                  a  Cereals and potatoes             Legumes
# 35783                  d         Sugary snacks  Chocolate products
# 35787                  d         Sugary snacks  Chocolate products
# 39150                  a                   NaN                 NaN
# 40977                  a                   NaN                 NaN
# 60706                  a                   NaN                 NaN
# 64677                  b               unknown             unknown
# 69736                  b               unknown             unknown
# 74374                  b                   NaN                 NaN
# 76931                  a                   NaN                 NaN
# 77031                  b                   NaN                 NaN
# 77943                  a                   NaN                 NaN
# 77946                  a                   NaN                 NaN
#
#        energy_100g  fat_100g  saturated-fat_100g  carbohydrates_100g  \
# 512         1464.0       NaN                0.00                 NaN
# 10896       1316.0       2.3                0.40                44.0
# 21133       1369.0       3.5                1.50                21.5
# 35672       1443.0       1.6                0.30                58.0
# 35783       2339.0       NaN               27.00                 NaN
# 35787       2339.0      45.0               22.00                22.0
# 39150        222.0       NaN                0.00                 NaN
# 40977        397.0       NaN                1.93                 NaN
# 60706       1385.0       NaN                0.28                 NaN
# 64677       2248.0      43.0                5.00                26.0
# 69736       1414.0       6.0                1.00                33.0
# 74374       1536.0       NaN                1.00                 NaN
# 76931       1695.0       NaN                1.90                 NaN
# 77031       1695.0       NaN                1.90                 NaN
# 77943       1397.0       NaN                0.40                 NaN
# 77946       1414.0       NaN                0.30                 NaN
#
#        sugars_100g  fiber_100g  proteins_100g  salt_100g
# 512           0.00        20.0           10.0      0.350
# 10896         3.90        20.0           19.0      0.060
# 21133         2.00        20.0           42.0      0.380
# 35672         3.90        20.0           24.0      0.000
# 35783        16.00        20.0            9.0      0.010
# 35787        16.00        20.0            9.0      0.010
# 39150        11.00        20.0            0.0      0.000
# 40977         0.72        20.0           12.5      0.980
# 60706         1.80        20.0           24.0      0.010
# 64677         1.00        20.0           20.0      0.053
# 69736        12.00        20.0           27.0      1.000
# 74374         2.50        20.0           11.0      1.500
# 76931        11.70        20.0           14.6      0.050
# 77031        21.00        20.0           14.6      0.050
# 77943         1.50        20.0            9.0      1.000
# 77946         3.50        20.0            9.5      1.150

# %% [markdown]
# Données cohérentes

# %% [markdown]
# #### Proteins_100g

# %%
print('Pourcentage de valeur à neutraliser : ',round(df.loc[df['proteins_100g']>40,'proteins_100g'].count()/df['proteins_100g'].count()*100,2),'%')
# Out:
# Pourcentage de valeur à neutraliser :  0.35 %

# %%
df.loc[df['proteins_100g']>40,'proteins_100g'] = np.nan
plt.title("Quantité de protéines par produit")
plt.ylabel('Protéines')
plt.xlabel('Numéro de produit')
plt.plot(df['proteins_100g'])
plt.show()

# %%
df[df['proteins_100g']==40].head()
# Out:
#                                             product_name  \
# 1212                                   Viande De Grisons
# 1215                                  Viande des Grisons
# 3444                     Lomo Embuchado - Longe de porc
# 12219  Evian fruits & plantes eau des alpes + citron ...
# 13051                                  Fluette De Jambon
#
#                                              packaging     brands  \
# 1212                                               NaN  Carrefour
# 1215   Barquette,Plastique,Sous atmosphère protectrice  Carrefour
# 3444                                 Blister plastique  Sol & Mar
# 12219                                              NaN      Evian
# 13051                                              NaN      Loste
#
#        additives_n nutrition_grade_fr   pnns_groups_1   pnns_groups_2  \
# 1212           NaN                  d             NaN             NaN
# 1215           2.0                  d  Fish Meat Eggs  Processed meat
# 3444           5.0                  d         unknown         unknown
# 12219          NaN                  d             NaN             NaN
# 13051          NaN                  d  Fish Meat Eggs  Processed meat
#
#        energy_100g  fat_100g  saturated-fat_100g  carbohydrates_100g  \
# 1212         812.0       NaN                 3.4                 NaN
# 1215         818.0       3.4                 1.4                 0.5
# 3444         987.0       8.0                 3.4                 1.0
# 12219       1046.0       NaN                 2.0                 NaN
# 13051       1059.0       NaN                 3.6                 NaN
#
#        sugars_100g  fiber_100g  proteins_100g  salt_100g
# 1212           1.4         0.5           40.0        4.4
# 1215           0.5         0.5           40.0        4.4
# 3444           1.0         NaN           40.0        5.0
# 12219         25.0         0.0           40.0        2.0
# 13051          3.0         0.0           40.0        4.2

# %% [markdown]
# Données cohérentes

# %% [markdown]
# #### Salt_100g

# %%
print('Pourcentage de valeur à neutraliser : ',round(df.loc[df['salt_100g']>100,'salt_100g'].count()/df['salt_100g'].count()*100,2),'%')
# Out:
# Pourcentage de valeur à neutraliser :  0.0 %

# %%
df.loc[df['salt_100g']>100,'salt_100g'] = np.nan
plt.title("Quantité de sel par produit")
plt.ylabel('Quantité de sel')
plt.xlabel('Numéro de produit')
plt.plot(df['salt_100g'])
plt.show()

# %%
df[df['salt_100g']==100].head()
# Out:
#                           product_name            packaging  \
# 15774           Moulin Sel de Guérande  Flacon,Verre,Moulin
# 17921  Véritable sel de mer la baleine                  NaN
# 17923           Le saunier de camargue                  NaN
# 22146                  Sel de Guérande               Carton
# 25456              Sel fin de Guerande                  NaN
#
#                         brands  additives_n nutrition_grade_fr pnns_groups_1  \
# 15774                   Ducros          0.0                  c       unknown
# 17921               La baleine          NaN                  c           NaN
# 17923   Le Saunier De Gamargue          NaN                  e       unknown
# 22146        Reflets de France          0.0                  c       unknown
# 25456  Itineraires des saveurs          NaN                  c       unknown
#
#       pnns_groups_2  energy_100g  fat_100g  saturated-fat_100g  \
# 15774       unknown          8.0       NaN                 0.1
# 17921           NaN          0.0       NaN                 0.0
# 17923       unknown        243.0       NaN                36.0
# 22146       unknown          0.0       NaN                 0.0
# 25456       unknown          0.0       NaN                 0.0
#
#        carbohydrates_100g  sugars_100g  fiber_100g  proteins_100g  salt_100g
# 15774                 NaN          0.0         0.0           0.08      100.0
# 17921                 NaN          0.0         0.0           0.00      100.0
# 17923                 NaN          0.5         0.0            NaN      100.0
# 22146                 NaN          0.0         0.0           0.00      100.0
# 25456                 NaN          0.0         0.0           0.00      100.0

# %% [markdown]
# Quelques données incohérentes, un filtre à faire selon la catégorie ?

# %% [markdown]
# ### 2.3 Traitement des lignes aberrantes

# %%
df.head()
# Out:
#                         product_name         packaging            brands  \
# 0                 Farine de blé noir               NaN   Ferme t'y R'nao
# 1                      Filet de bœuf         plastique               NaN
# 2                            Twix x2               NaN               NaN
# 3                  lentilles vertes   Sachet plastique  Bertrand Lejeune
# 4  Biscuits sablés fourrage au cacao      Carton,boîte         St Michel
#
#    additives_n nutrition_grade_fr         pnns_groups_1       pnns_groups_2  \
# 0          NaN                NaN                   NaN                 NaN
# 1          NaN                NaN               unknown             unknown
# 2          NaN                NaN               unknown             unknown
# 3          0.0                NaN  Cereals and potatoes             Legumes
# 4          3.0                NaN         Sugary snacks  Biscuits and cakes
#
#    energy_100g  fat_100g  saturated-fat_100g  carbohydrates_100g  sugars_100g  \
# 0          NaN       NaN                 NaN                 NaN          NaN
# 1          NaN       NaN                 NaN                 NaN          NaN
# 2          NaN       NaN                 NaN                 NaN          NaN
# 3          NaN       NaN                 NaN                 NaN          NaN
# 4          NaN       NaN                 NaN                 NaN          NaN
#
#    fiber_100g  proteins_100g  salt_100g
# 0         NaN            NaN        NaN
# 1         NaN            NaN        NaN
# 2         NaN            NaN        NaN
# 3         NaN            NaN        NaN
# 4         NaN            NaN        NaN

# %%
col_interet = ['fat_100g','carbohydrates_100g','fiber_100g','proteins_100g','salt_100g']
a = np.sum(df.loc[:,col_interet], axis = 1)>102

# %% [markdown]
# On laisse une marge de 2% d'erreurs et supprime les autres données

# %%
max(df.count())
# Out:
# 86881

# %%
df.drop(df[a].index,axis = 0, inplace = True)

# %%
max(df.count())
# Out:
# 86716

# %% [markdown]
# ##### Saturated_fat > fat

# %%
df.loc[df['saturated-fat_100g']>df['fat_100g']]
# Out:
#                           product_name  \
# 736         Sriracha Stærk Chili Sauce
# 3047                 Amandes en poudre
# 3264                  Macarons de coco
# 3315   Favorina, Haselnuss Nougat Eier
# 7011         Bonbons Cassis Sans Sucre
# ...                                ...
# 80674             Ginger San Benedetto
# 81340                 Tic Tac - Menthe
# 81401                   Tic Tac Menthe
# 82451                        Buongrano
# 86245      sweet sour sauce thai pride
#
#                                                packaging              brands  \
# 736                                                  NaN         Royal canin
# 3047   Sachet,Plastique,Plastique 05,Polypropylène,sa...  Maerschimport,Lidl
# 3264                                    Sachet plastique              Sondey
# 3315                                                 NaN            Favorina
# 7011                                              Carton           Feel free
# ...                                                  ...                 ...
# 80674                                                NaN       San benedetto
# 81340                                          Plastique             Tic Tac
# 81401                                    Boite plastique             Tic Tac
# 82451                                                NaN       Mulino Bianco
# 86245                                          bouteille          thai pride
#
#        additives_n nutrition_grade_fr   pnns_groups_1         pnns_groups_2  \
# 736            4.0                  d         unknown               unknown
# 3047           0.0                  d         unknown               unknown
# 3264           3.0                  e   Sugary snacks    Biscuits and cakes
# 3315           3.0                  e             NaN                   NaN
# 7011           4.0                  b   Sugary snacks                Sweets
# ...            ...                ...             ...                   ...
# 80674          NaN                  d             NaN                   NaN
# 81340          2.0                  d   Sugary snacks                Sweets
# 81401          2.0                  d   Sugary snacks                Sweets
# 82451          NaN                  c             NaN                   NaN
# 86245          NaN                NaN  Fat and sauces  Dressings and sauces
#
#        energy_100g  fat_100g  saturated-fat_100g  carbohydrates_100g  \
# 736          510.0      0.00                 0.1               28.00
# 3047        2570.0     54.80                73.8                7.00
# 3264        1990.0     23.00                23.1               60.00
# 3315        2360.0      9.94                14.5                7.05
# 7011        1000.0      0.00                 0.5               98.00
# ...            ...       ...                 ...                 ...
# 80674         13.0      0.00                 2.5                6.30
# 81340       1661.0      0.30                 0.5               97.50
# 81401       1661.0      0.00                 0.5               97.50
# 82451       1891.0      0.00                 1.6                0.00
# 86245        194.0      0.00                 2.0               11.00
#
#        sugars_100g  fiber_100g  proteins_100g  salt_100g
# 736          18.00         0.0            1.8    7.31520
# 3047          5.50         9.4           20.5    0.07000
# 3264         48.00         NaN            4.5    0.20000
# 3315         48.60         0.0            8.2    0.66040
# 7011          0.50         0.5            0.0    0.00000
# ...            ...         ...            ...        ...
# 80674         1.73         0.0            3.0    6.00000
# 81340        94.50         0.0            0.1    0.02800
# 81401        94.50         0.0            0.1    0.02800
# 82451        20.50         8.7            7.7    0.54300
# 86245         8.50         NaN            NaN    0.75438
#
# [75 rows x 15 columns]

# %%
df.loc[df['saturated-fat_100g']>df['fat_100g'],('fat_100g','saturated-fat_100g')] = np.nan

# %%
df.loc[df['saturated-fat_100g']>df['fat_100g']]
# Out:
# Empty DataFrame
# Columns: [product_name, packaging, brands, additives_n, nutrition_grade_fr, pnns_groups_1, pnns_groups_2, energy_100g, fat_100g, saturated-fat_100g, carbohydrates_100g, sugars_100g, fiber_100g, proteins_100g, salt_100g]
# Index: []

# %% [markdown]
# ##### sugars > carbohydrates

# %%
df.loc[df['sugars_100g']>df['carbohydrates_100g']]
# Out:
#                              product_name  \
# 1761                          Alo exposed
# 3315      Favorina, Haselnuss Nougat Eier
# 3757         Fromage blanc saveur vanille
# 3758            Fromage blanc 20 % nature
# 3925           Foie gras de canard entier
# ...                                   ...
# 80899              Mielbio de Châtaignier
# 82451                           Buongrano
# 83449                          Chiffonade
# 84059  Filets d'anchois à l'huile d'olive
# 85621         Ben & Jerry's - Fairly Nuts
#
#                                                packaging             brands  \
# 1761                                                 NaN                Alo
# 3315                                                 NaN           Favorina
# 3757                                      Pots,Plastique            Milbona
# 3758                                carton,pot plastique            Milbona
# 3925   Frais,Boîte,Carton,Plastique,Semi-conserve,Sou...  G succes gourmand
# ...                                                  ...                ...
# 80899                                        Bocal,verre   Rigoni di asiago
# 82451                                                NaN      Mulino Bianco
# 83449                          Barquette,Plastique,Frais         Casa Ramon
# 84059                                       pot de verre                Dia
# 85621                                            Surgelé      Ben & Jerry's
#
#        additives_n nutrition_grade_fr            pnns_groups_1  \
# 1761           NaN                  c                      NaN
# 3315           3.0                  e                      NaN
# 3757           5.0                  b  Milk and dairy products
# 3758           0.0                  a  Milk and dairy products
# 3925           1.0                  e                  unknown
# ...            ...                ...                      ...
# 80899          0.0                  d            Sugary snacks
# 82451          NaN                  c                      NaN
# 83449          2.0                  d           Fish Meat Eggs
# 84059          0.0                  d           Fish Meat Eggs
# 85621          5.0                  d  Milk and dairy products
#
#           pnns_groups_2  energy_100g  fat_100g  saturated-fat_100g  \
# 1761                NaN        251.0       0.0                 0.0
# 3315                NaN       2360.0       NaN                 NaN
# 3757             Cheese        406.0       2.2                 1.5
# 3758             Cheese        305.0       3.3                 2.0
# 3925            unknown       2276.0      59.9                23.6
# ...                 ...          ...       ...                 ...
# 80899            Sweets       1347.0       0.0                 0.0
# 82451               NaN       1891.0       NaN                 NaN
# 83449    Processed meat        853.0       8.2                 3.1
# 84059  Fish and seafood        825.0      11.0                 3.2
# 85621         Ice cream       1172.0      15.0                11.0
#
#        carbohydrates_100g  sugars_100g  fiber_100g  proteins_100g  salt_100g
# 1761                 6.25         15.0         0.0            0.0    0.03048
# 3315                 7.05         48.6         0.0            8.2    0.66040
# 3757                13.00         14.0         0.0            5.4    0.08000
# 3758                 3.50          3.9         0.0            7.3    0.10000
# 3925                 1.72          2.2         0.0            7.5    1.27000
# ...                   ...          ...         ...            ...        ...
# 80899               75.00         80.0         0.0            0.0    0.00000
# 82451                0.00         20.5         8.7            7.7    0.54300
# 83449                0.10          0.3         NaN           32.3    4.96000
# 84059                1.60          2.0         0.0           23.0   15.72000
# 85621               23.00         26.0         0.0            4.0    0.21000
#
# [89 rows x 15 columns]

# %%
df.loc[df['sugars_100g']>df['carbohydrates_100g'],('carbohydrates_100g','sugars_100g')] = np.nan

# %%
df.loc[df['sugars_100g']>df['carbohydrates_100g']]
# Out:
# Empty DataFrame
# Columns: [product_name, packaging, brands, additives_n, nutrition_grade_fr, pnns_groups_1, pnns_groups_2, energy_100g, fat_100g, saturated-fat_100g, carbohydrates_100g, sugars_100g, fiber_100g, proteins_100g, salt_100g]
# Index: []

# %% [markdown]
# ##### Suppression des alcools

# %%
df.drop(df[df['pnns_groups_2']=="Alcoholic beverages"].index,axis = 0,inplace = True)

# %%
df.boxplot()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## 3. Valeurs manquantes

# %% [markdown]
# ##### Nombre de NaN par lignes

# %%
#plt.hist(df.isnull().sum(axis = 1).uniques(),df.isnull().sum(axis = 1).count())
#print(len(df.columns))
plt.title = "Nombre de ligne selon le nombre de NAN"
plt.xlabel = "Nombre de Nan"
plt.ylabel = "Nombre de lignes"
plt.barh(df.isnull().sum(axis = 1).value_counts().index,df.isnull().sum(axis = 1).value_counts())
plt.show()

# %%
df.head()
# Out:
#                         product_name         packaging            brands  \
# 0                 Farine de blé noir               NaN   Ferme t'y R'nao
# 1                      Filet de bœuf         plastique               NaN
# 2                            Twix x2               NaN               NaN
# 3                  lentilles vertes   Sachet plastique  Bertrand Lejeune
# 4  Biscuits sablés fourrage au cacao      Carton,boîte         St Michel
#
#    additives_n nutrition_grade_fr         pnns_groups_1       pnns_groups_2  \
# 0          NaN                NaN                   NaN                 NaN
# 1          NaN                NaN               unknown             unknown
# 2          NaN                NaN               unknown             unknown
# 3          0.0                NaN  Cereals and potatoes             Legumes
# 4          3.0                NaN         Sugary snacks  Biscuits and cakes
#
#    energy_100g  fat_100g  saturated-fat_100g  carbohydrates_100g  sugars_100g  \
# 0          NaN       NaN                 NaN                 NaN          NaN
# 1          NaN       NaN                 NaN                 NaN          NaN
# 2          NaN       NaN                 NaN                 NaN          NaN
# 3          NaN       NaN                 NaN                 NaN          NaN
# 4          NaN       NaN                 NaN                 NaN          NaN
#
#    fiber_100g  proteins_100g  salt_100g
# 0         NaN            NaN        NaN
# 1         NaN            NaN        NaN
# 2         NaN            NaN        NaN
# 3         NaN            NaN        NaN
# 4         NaN            NaN        NaN

# %%
from importlib import reload
reload(plt)
# Out:
# <module 'matplotlib.pyplot' from '/home/fayz/Documents/OpenClassrooms/Projet2/p2/lib/python3.8/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# ##### Proportion de lignes où il y a plus de 10 colonnes vides sur 14

# %%
col_vides = (df.isnull().sum(axis = 1) >= 10) & ((df.pnns_groups_1 == 'unknown') | (df.pnns_groups_1.isna()))
col_vides_prop = col_vides.value_counts()/a.count()*100
col_vides_prop.plot.pie()
plt.ylabel("Plus de 10 colonnes vides")
print(col_vides_prop)
# Out:
# False    82.438047
# True     15.238084
# dtype: float64

# %%
df.drop(df[col_vides].index, axis = 0, inplace = True)

# %% [markdown]
# ##### Remplissage des données - logique métier

# %%
df.additives_n = df.additives_n.fillna(round(np.mean(df.additives_n),0))

# %%
df.fiber_100g = df.fiber_100g.fillna(0)

# %%
#df.loc[df['pnns_groups_1']=="Beverages",'fat_100g'] = df.loc[df['pnns_groups_1']=="Beverages"].fat_100g.fillna(tab_med.fat_100g['Beverages'])

# %%
#tab_mean = df.groupby('pnns_groups_1').mean()

# %% [markdown]
# ##### Remplissage par la médiane par catégorie de produit

# %%
# Remplissage par la mediane, on donne le tableau, 
#                           la colonne sur laquelle on a fait le group_by (dans notre cas pnns_groups_1 mais peut changer donc mis en paramètre pour plus de souplesse)
import math
def remplissage_mean(df,feat_groupby):
    tab_med = df.groupby(feat_groupby).mean()
    #print(tab_med)
    for i in tab_med.columns:
        for j in df[feat_groupby].unique():
            try:
                if(math.isnan(j)):
                    continue                
            except:
                df.loc[df[feat_groupby]==j,i] = df.loc[df[feat_groupby]==j][i].fillna(tab_med[i][j])
    return df

# %%
#remplissage_median(df,'pnns_groups_1')

# %%
df.count()
# Out:
# product_name          71623
# packaging             51315
# brands                71165
# additives_n           71623
# nutrition_grade_fr    57875
# pnns_groups_1         57858
# pnns_groups_2         57906
# energy_100g           60660
# fat_100g              43894
# saturated-fat_100g    58678
# carbohydrates_100g    43464
# sugars_100g           58749
# fiber_100g            71623
# proteins_100g         60290
# salt_100g             58896
# dtype: int64

# %%
df = remplissage_mean(df,'pnns_groups_2')

# %%
df.loc[df['saturated-fat_100g']>df['fat_100g'],'fat_100g'] = np.nan

# %%
df.loc[df['sugars_100g']>df['carbohydrates_100g'],'carbohydrates_100g'] = np.nan

# %%
col = df.columns
col_nombre = df.count()
plt.title('Taux de remplissage des colonnes')
plt.ylabel("Nom de colonne")
plt.xlabel("Taux de non vide en %")
plt.barh(col,col_nombre/col_nombre[0]*100)
plt.axvline(x=70)
plt.axvline(x=80)
plt.show()

# %%
df.count()
# Out:
# product_name          71623
# packaging             51315
# brands                71165
# additives_n           71623
# nutrition_grade_fr    57875
# pnns_groups_1         57858
# pnns_groups_2         57906
# energy_100g           71569
# fat_100g              56891
# saturated-fat_100g    71617
# carbohydrates_100g    56663
# sugars_100g           71617
# fiber_100g            71623
# proteins_100g         71511
# salt_100g             71617
# dtype: int64

# %% [markdown]
# ##### Impute iterative

# %%
df.corr()
# Out:
#                     additives_n  energy_100g  fat_100g  saturated-fat_100g  \
# additives_n            1.000000     0.051782  0.000174           -0.000696
# energy_100g            0.051782     1.000000  0.779198            0.583882
# fat_100g               0.000174     0.779198  1.000000            0.751514
# saturated-fat_100g    -0.000696     0.583882  0.751514            1.000000
# carbohydrates_100g     0.123060     0.508692 -0.072026           -0.031030
# sugars_100g            0.102922     0.320215 -0.015720            0.068625
# fiber_100g            -0.040940     0.225432  0.012229           -0.034506
# proteins_100g         -0.049641     0.207030  0.157293            0.163896
# salt_100g              0.006540    -0.016494  0.026199            0.010932
#
#                     carbohydrates_100g  sugars_100g  fiber_100g  \
# additives_n                   0.123060     0.102922   -0.040940
# energy_100g                   0.508692     0.320215    0.225432
# fat_100g                     -0.072026    -0.015720    0.012229
# saturated-fat_100g           -0.031030     0.068625   -0.034506
# carbohydrates_100g            1.000000     0.654420    0.291792
# sugars_100g                   0.654420     1.000000    0.048423
# fiber_100g                    0.291792     0.048423    1.000000
# proteins_100g                -0.155071    -0.284048    0.085988
# salt_100g                    -0.077323    -0.095008   -0.025287
#
#                     proteins_100g  salt_100g
# additives_n             -0.049641   0.006540
# energy_100g              0.207030  -0.016494
# fat_100g                 0.157293   0.026199
# saturated-fat_100g       0.163896   0.010932
# carbohydrates_100g      -0.155071  -0.077323
# sugars_100g             -0.284048  -0.095008
# fiber_100g               0.085988  -0.025287
# proteins_100g            1.000000   0.105360
# salt_100g                0.105360   1.000000

# %%
# !pip3 install sklearn
# Out:
# Requirement already satisfied: sklearn in ./p2/lib/python3.8/site-packages (0.0)
# Requirement already satisfied: scikit-learn in ./p2/lib/python3.8/site-packages (from sklearn) (1.0.2)
# Requirement already satisfied: numpy>=1.14.6 in ./p2/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.22.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./p2/lib/python3.8/site-packages (from scikit-learn->sklearn) (3.1.0)
# Requirement already satisfied: scipy>=1.1.0 in ./p2/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.8.0)
# Requirement already satisfied: joblib>=0.11 in ./p2/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.1.0)

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
df[df['fat_100g'].isna()]
# Out:
#                                         product_name packaging  \
# 7                                     Mini Confettis       NaN
# 8                         Praliné Amande Et Noisette       NaN
# 14                         Tarte Poireaux Et Lardons       NaN
# 24                               Beignets framboises       NaN
# 44                   Black & White Crispbread Sticks       NaN
# ...                                              ...       ...
# 86852  Peanut & Popcorn With Dark Chocolate 12 x 45G       NaN
# 86853                     Eat Natural Protein Packed       NaN
# 86869                     Verrine Cheescake Myrtille       NaN
# 86870                                   Fiche Brevet       NaN
# 86874                                        Amandes       NaN
#
#                   brands  additives_n nutrition_grade_fr pnns_groups_1  \
# 7           Alice Délice          2.0                  d           NaN
# 8           Alice Délice          2.0                  d           NaN
# 14              Bo Frost          2.0                  d           NaN
# 24           Intermarché          2.0                  c           NaN
# 44     Swedish By Nature          2.0                  d           NaN
# ...                  ...          ...                ...           ...
# 86852        Great value          2.0                  d           NaN
# 86853             Biobio          2.0                  d           NaN
# 86869             Kayser          2.0                  d           NaN
# 86870             Hatier          2.0                  b           NaN
# 86874             Biosic          2.0                  b           NaN
#
#       pnns_groups_2  energy_100g  fat_100g  saturated-fat_100g  \
# 7               NaN       1753.0       NaN                0.80
# 8               NaN       2406.0       NaN                2.90
# 14              NaN       1079.0       NaN               11.00
# 24              NaN       1272.0       NaN                1.70
# 44              NaN       1674.0       NaN                1.80
# ...             ...          ...       ...                 ...
# 86852           NaN       1883.0       NaN                7.80
# 86853           NaN       1996.0       NaN               10.00
# 86869           NaN       1084.0       NaN               12.00
# 86870           NaN          4.0       NaN                1.00
# 86874           NaN       2406.0       NaN                3.73
#
#        carbohydrates_100g  sugars_100g  fiber_100g  proteins_100g  salt_100g
# 7                     NaN        87.70         0.9           0.60      0.010
# 8                     NaN        50.30         3.9           9.50      0.003
# 14                    NaN         1.00         1.4           7.50      0.800
# 24                    NaN        12.70         0.0           5.80      0.700
# 44                    NaN         5.50        10.0          15.00      2.400
# ...                   ...          ...         ...            ...        ...
# 86852                 NaN        34.10         5.4          10.90      0.400
# 86853                 NaN        22.00         6.0          22.00      1.000
# 86869                 NaN        10.50         0.0           8.70      0.290
# 86870                 NaN         1.00        10.0          10.00     10.000
# 86874                 NaN         3.89        12.2          21.22      0.100
#
# [14732 rows x 15 columns]

# %%
df.count()
# Out:
# product_name          71623
# packaging             51315
# brands                71165
# additives_n           71623
# nutrition_grade_fr    57875
# pnns_groups_1         57858
# pnns_groups_2         57906
# energy_100g           71569
# fat_100g              56891
# saturated-fat_100g    71617
# carbohydrates_100g    56663
# sugars_100g           71617
# fiber_100g            71623
# proteins_100g         71511
# salt_100g             71617
# dtype: int64

# %%
imp = IterativeImputer()

# %%
X = df.loc[:,('fat_100g','saturated-fat_100g')]

# %%
imp.fit(X)
# Out:
# IterativeImputer()

# %%
imp.transform(X)[:,0]
# Out:
# array([ 5.58134236, 19.98489976,  1.61882586, ...,  7.4706872 ,
#         0.2       , 17.59695427])

# %%
df.loc[df['saturated-fat_100g']>df['fat_100g']]
# Out:
# Empty DataFrame
# Columns: [product_name, packaging, brands, additives_n, nutrition_grade_fr, pnns_groups_1, pnns_groups_2, energy_100g, fat_100g, saturated-fat_100g, carbohydrates_100g, sugars_100g, fiber_100g, proteins_100g, salt_100g]
# Index: []

# %%
df = df.reset_index()
df.drop('index',axis = 1, inplace = True)

# %%
df['fat_100g'] = imp.transform(X)[:,0]

# %%
#df.loc[df['saturated-fat_100g']>df['fat_100g']]

# %%
X = df.loc[:,('carbohydrates_100g','sugars_100g')]

# %%
imp2 = IterativeImputer()

# %%
imp2.fit(X)
# Out:
# IterativeImputer()

# %%
df['carbohydrates_100g'] = imp2.transform(X)[:,0]

# %%
df.describe()
# Out:
#         additives_n   energy_100g      fat_100g  saturated-fat_100g  \
# count  71623.000000  71569.000000  71623.000000        71617.000000
# mean       1.937143   1082.765351     13.278371            5.243312
# std        2.132159    748.258867     15.932337            8.028994
# min        0.000000      0.000000      0.000000            0.000000
# 25%        0.000000    423.000000      2.600000            0.400000
# 50%        2.000000   1016.022714      7.800000            2.244839
# 75%        2.000000   1582.000000     19.000000            6.772240
# max       31.000000   4000.000000    165.096360          100.000000
#
#        carbohydrates_100g   sugars_100g    fiber_100g  proteins_100g  \
# count        71623.000000  71617.000000  71623.000000   71511.000000
# mean            27.250724     13.054846      1.322196       7.577575
# std             25.063588     18.296174      2.501833       7.098734
# min              0.000000      0.000000      0.000000       0.000000
# 25%              7.000000      1.100000      0.000000       1.900000
# 50%             17.000000      4.400000      0.000000       6.068690
# 75%             48.418121     16.000000      1.800000      10.700000
# max            112.508891    100.000000     20.000000      40.000000
#
#           salt_100g
# count  71617.000000
# mean       1.135383
# std        3.754062
# min        0.000000
# 25%        0.100000
# 50%        0.600000
# 75%        1.369775
# max      100.000000

# %% [markdown]
# Retrait des IterativeImputer absurde

# %%
df.loc[df.fat_100g>100,'fat_100g'] = np.nan
df.loc[df['carbohydrates_100g']>100,'carbohydrates_100g'] = np.nan
df.loc[df.fat_100g<0,'fat_100g'] = np.nan
df.loc[df.energy_100g==0,'energy_100g'] = np.nan
df.describe()
# Out:
#         additives_n   energy_100g      fat_100g  saturated-fat_100g  \
# count  71623.000000  71264.000000  71534.000000        71617.000000
# mean       1.937143   1087.399436     13.135015            5.243312
# std        2.132159    746.490757     15.397813            8.028994
# min        0.000000      0.420000      0.000000            0.000000
# 25%        0.000000    431.000000      2.600000            0.400000
# 50%        2.000000   1016.022714      7.761579            2.244839
# 75%        2.000000   1585.000000     19.000000            6.772240
# max       31.000000   4000.000000    100.000000          100.000000
#
#        carbohydrates_100g   sugars_100g    fiber_100g  proteins_100g  \
# count        71485.000000  71617.000000  71623.000000   71511.000000
# mean            27.093627     13.054846      1.322196       7.577575
# std             24.830589     18.296174      2.501833       7.098734
# min              0.000000      0.000000      0.000000       0.000000
# 25%              7.000000      1.100000      0.000000       1.900000
# 50%             16.998718      4.400000      0.000000       6.068690
# 75%             48.418121     16.000000      1.800000      10.700000
# max            100.000000    100.000000     20.000000      40.000000
#
#           salt_100g
# count  71617.000000
# mean       1.135383
# std        3.754062
# min        0.000000
# 25%        0.100000
# 50%        0.600000
# 75%        1.369775
# max      100.000000

# %%
col = df.columns
col_nombre = df.count()
plt.title('Taux de remplissage des colonnes')
plt.ylabel("Nom de colonne")
plt.xlabel("Taux de non vide en %")
plt.barh(col,col_nombre/col_nombre[0]*100)
plt.axvline(x=70)
plt.axvline(x=80)
plt.axvline(x=100)
plt.figure(figsize=(20, 10))
plt.show()

# %%
df = df.drop_duplicates()
df.count()
# Out:
# product_name          71621
# packaging             51313
# brands                71163
# additives_n           71621
# nutrition_grade_fr    57873
# pnns_groups_1         57856
# pnns_groups_2         57904
# energy_100g           71262
# fat_100g              71532
# saturated-fat_100g    71615
# carbohydrates_100g    71483
# sugars_100g           71615
# fiber_100g            71621
# proteins_100g         71509
# salt_100g             71615
# dtype: int64

# %% [markdown]
# ### Dernière vérification

# %%
#df.loc[df['saturated-fat_100g']>df['fat_100g']]

# %%
#df.loc[df['sugars_100g']>df['carbohydrates_100g']]

# %%
col_interet = ['fat_100g','carbohydrates_100g','fiber_100g','proteins_100g','salt_100g']
a = np.sum(df.loc[:,col_interet], axis = 1)>105
df[a]
df.drop(df[a].index,axis = 0, inplace = True)

# %% [markdown]
# ### Extract

# %% [markdown]
# On a bien rempli la quasi-totalité de nos valeurs quantitatives, et pouvont à présent, effectuer notre analyse exploratoire

# %% [markdown]
# Sauvegarde de notre jeu de données dans un fichier .csv

# %%
df.to_csv('/home/fayz/Documents/OpenClassrooms/Projet2/food_clean.csv',index = False)
